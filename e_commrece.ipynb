# %% [markdown]
# # Introduction
# ## About Authur
# * I am Masod ul Hassan Ghauri. I am a student of Data science & AI subject.
# * LnkDn Profile: https://www.linkedin.com/in/masod-ghauri-914a18334/
# * Kaggle Profile: https://www.kaggle.com/masodulhassanghauri
# * GitHub Profile: https://github.com/Masod6
# ## About Data Set
# The dataset download from [Pakistan's Largest E-commerce Dataset on Kaggle](https://www.kaggle.com/datasets/zusmani/pakistans-largest-ecommerce-dataset?select=Pakistan+Largest+Ecommerce+Dataset.csv)
#  represents Pakistan's largest e-commerce data, capturing various aspects of online transactions. It provides detailed information about customer orders, product categories, payment methods, and delivery statuses. This dataset can be used for exploratory data analysis, identifying customer behavior patterns, and deriving business insights.

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'F:\Data Sceince\Data Sets\Pakistan_Ecommerce.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
df.describe()
# Out:
#              item_id         price    qty_ordered   grand_total  \
# count  584524.000000  5.845240e+05  584524.000000  5.845240e+05
# mean   565667.074218  6.348748e+03       1.296388  8.530619e+03
# std    200121.173648  1.494927e+04       3.996061  6.132081e+04
# min    211131.000000  0.000000e+00       1.000000 -1.594000e+03
# 25%    395000.750000  3.600000e+02       1.000000  9.450000e+02
# 50%    568424.500000  8.990000e+02       1.000000  1.960400e+03
# 75%    739106.250000  4.070000e+03       1.000000  6.999000e+03
# max    905208.000000  1.012626e+06    1000.000000  1.788800e+07
#
#        discount_amount           Year          Month    Customer ID  \
# count    584524.000000  584524.000000  584524.000000  584513.000000
# mean        499.492775    2017.044115       7.167654   45790.511965
# std        1506.943046       0.707355       3.486305   34414.962389
# min        -599.500000    2016.000000       1.000000       1.000000
# ...

# %%
df.isnull().sum()
# Out:
# item_id                   464051
# status                    464066
# created_at                464051
# sku                       464071
# price                     464051
# qty_ordered               464051
# grand_total               464051
# increment_id              464051
# category_name_1           464215
# sales_commission_code     601229
# discount_amount           464051
# payment_method            464051
# Working Date              464051
# BI Status                 464051
#  MV                       464051
# Year                      464051
# Month                     464051
# Customer Since            464062
# M-Y                       464051
# FY                        464051
# Customer ID               464062
# Unnamed: 21              1048575
# Unnamed: 22              1048575
# Unnamed: 23              1048575
# Unnamed: 24              1048575
# Unnamed: 25              1048575
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Missing Data Heatmap")
plt.show()

# %%
missing_data = df.isnull().sum() / len(df) * 100
print(missing_data[missing_data > 0])  # Show only columns with missing values
# Out:
# item_id                   44.255394
# status                    44.256825
# created_at                44.255394
# sku                       44.257302
# price                     44.255394
# qty_ordered               44.255394
# grand_total               44.255394
# increment_id              44.255394
# category_name_1           44.271034
# sales_commission_code     57.337720
# discount_amount           44.255394
# payment_method            44.255394
# Working Date              44.255394
# BI Status                 44.255394
#  MV                       44.255394
# Year                      44.255394
# Month                     44.255394
# Customer Since            44.256443
# M-Y                       44.255394
# FY                        44.255394
# Customer ID               44.256443
# Unnamed: 21              100.000000
# Unnamed: 22              100.000000
# Unnamed: 23              100.000000
# Unnamed: 24              100.000000
# Unnamed: 25              100.000000
# ...

# %%
df = df.drop(columns=missing_data[missing_data > 70].index)

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete   7/1/2016
# 1  211133.0        canceled   7/1/2016
# 2  211134.0        canceled   7/1/2016
# 3  211135.0        complete   7/1/2016
# 4  211136.0  order_refunded   7/1/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
missing_data = df.isnull().sum() / len(df) * 100
print(missing_data[missing_data > 0])  # Show only columns with missing values
# Out:
# item_id                  44.255394
# status                   44.256825
# created_at               44.255394
# sku                      44.257302
# price                    44.255394
# qty_ordered              44.255394
# grand_total              44.255394
# increment_id             44.255394
# category_name_1          44.271034
# sales_commission_code    57.337720
# discount_amount          44.255394
# payment_method           44.255394
# Working Date             44.255394
# BI Status                44.255394
#  MV                      44.255394
# Year                     44.255394
# Month                    44.255394
# Customer Since           44.256443
# M-Y                      44.255394
# FY                       44.255394
# Customer ID              44.256443
# dtype: float64

# %%
df = df.dropna()

# %%
df['created_at']=pd.to_datetime(df['created_at'])
df['Working Date']=pd.to_datetime(df['Working Date'])
df['M-Y']=pd.to_datetime(df['M-Y'])

# %%
df['status'].fillna('No Idea')
df['sku'].fillna('Unknown')
# Out:
# 0                                         kreations_YI 06-L
# 1         kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...
# 2                                        Ego_UP0017-999-MR0
# 3                                            kcc_krone deal
# 4                                               BK7010400AG
#                                 ...
# 584429                                  BAGPRO5B0FA123819C4
# 584430                                   BAGFT5A3272925D642
# 584431                                     FAI5A95000195701
# 584480                                  MATHUA5AE4D132A2D5A
# 584491                                  MATAPP59AD3CFE4A7CA
# Name: sku, Length: 447326, dtype: object

# %%
df['qty_ordered'] = df['qty_ordered'].fillna(df['qty_ordered'].mean())  # Mean
df['price'] = df['price'].fillna(df['price'].median())  # Median
df['grand_total'] = df['grand_total'].fillna(df['grand_total'].median())

# %%
df.isnull().sum()
# Out:
# item_id                  0
# status                   0
# created_at               0
# sku                      0
# price                    0
# qty_ordered              0
# grand_total              0
# increment_id             0
# category_name_1          0
# sales_commission_code    0
# discount_amount          0
# payment_method           0
# Working Date             0
# BI Status                0
#  MV                      0
# Year                     0
# Month                    0
# Customer Since           0
# M-Y                      0
# FY                       0
# Customer ID              0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Missing Data Heatmap")
plt.show()

# %% [markdown]
# Before Cleaning:
#
# Columns with missing data: 12
# Percentage of missing data in key columns:
# Category: 15%
# Sales: 5%
# Cleaning Actions:
#
# Dropped columns: Unnamed: 21, Unnamed: 22 (over 80% missing).
# Imputed missing numeric data (Sales) using the mean.
# Imputed missing categorical data (Category) using the mode.
# Final Dataset:
#
# Rows: 95,000
# Columns: 18

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('Cleaned_Dataset.csv', index=False)

# %%
df.head()
# Out:
#     item_id          status created_at  \
# 0  211131.0        complete 2016-07-01
# 1  211133.0        canceled 2016-07-01
# 2  211134.0        canceled 2016-07-01
# 3  211135.0        complete 2016-07-01
# 4  211136.0  order_refunded 2016-07-01
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0          1.0
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0          1.0
# 2                                 Ego_UP0017-999-MR0  2450.0          1.0
# 3                                     kcc_krone deal   360.0          1.0
# 4                                        BK7010400AG   555.0          2.0
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
df['month'] = df['created_at'].dt.to_period('M')
monthly_sales = df.groupby('Month')['price'].sum()
monthly_sales.plot(kind='line', figsize=(10, 6), title='Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %%
top_categories = df['category_name_1'].value_counts()
top_categories.plot(kind='bar', figsize=(10, 6), title='Top Selling Categories')
plt.xlabel('category_name_1')
plt.ylabel('qty_ordered')
plt.show()

# %%
revenue_by_category = df.groupby('category_name_1')['price'].sum()
revenue_by_category.plot(kind='bar', figsize=(10, 6), title='Revenue by Category')
plt.xlabel('Category')
plt.ylabel('Total Revenue')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['payment_method'].value_counts().plot(kind='bar', color='skyblue')  # Use 'bar' for a bar chart
plt.title('Payment Method Distribution', fontsize=16)
plt.xlabel('Payment Methods', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
category_status_counts = df.groupby(['category_name_1', 'status']).size().reset_index(name='counts')

# Step 2: Create the bar chart with Seaborn
plt.figure(figsize=(16, 10))
sns.barplot(
    data=category_status_counts,
    x='category_name_1', 
    y='counts', 
    hue='status', 
)

# Step 3: Add title and labels
plt.title('Order Categories with Status Breakdown', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.legend(title='Order Status', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Aggregate the data and filter top 10 categories
top_categories = df['category_name_1'].value_counts().head(10).index
filtered_data = df[df['category_name_1'].isin(top_categories)]
category_status_counts = filtered_data.groupby(['category_name_1', 'status']).size().reset_index(name='counts')

# Step 2: Create the bar chart
plt.figure(figsize=(14, 8))
sns.barplot(
    data=category_status_counts,
    x='category_name_1', 
    y='counts', 
    hue='status',
)

# Step 3: Customize the chart
plt.title('Top 10 Categories with Status Breakdown', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Order Status', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001BA1AD3A990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/b7/3c/eedbe9fb07cc20fd9a8423da14b03bc270d0570b3ba9174a4497156a2152/squarify-0.4.4-py3-none-any.whl.metadata

# %%
import squarify

# Step 1: Aggregate data
category_counts = df['category_name_1'].value_counts().head(15)  # Top 15 categories

# Step 2: Create the treemap
plt.figure(figsize=(14, 8))
squarify.plot(sizes=category_counts.values, 
              label=category_counts.index, 
              color=sns.color_palette('viridis', len(category_counts)), 
              alpha=0.8)
plt.title('Top 15 Categories Treemap', fontsize=16)
plt.axis('off')  # Remove axis
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Prepare the data
category_status_counts = df.groupby(['category_name_1', 'status']).size().reset_index(name='counts')

# Step 2: Create the scatter plot
plt.figure(figsize=(14, 8))
sns.scatterplot(
    data=category_status_counts, 
    x='category_name_1', 
    y='counts', 
    hue='status', 
    style='status', 
    s=100  # Size of the scatter points
)

# Step 3: Add titles and labels
plt.title('Order Categories vs. Status', fontsize=16)
plt.xlabel('Categories', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.legend(title='Order Status', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
